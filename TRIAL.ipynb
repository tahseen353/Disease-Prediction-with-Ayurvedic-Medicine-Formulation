# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
# from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


# Text Preprocessing Function

def preprocess_text(text):
    # Tokenization
    words = word_tokenize(text.lower())
    # Removing stopwords and non-alphabetic characters
    words = [word for word in words if word.isalpha() and word not in stop_words]
    return ' '.join(words)


# Load the dataset

data = pd.read_csv('Symptom2Disease.csv') 

# Displaying the dataset

# print(data)

data.drop(columns=["Unnamed: 0"], inplace=True)

# Concise summary of DataFrame

# print(data.info())

# Check for null values

# print(data.isnull().sum())

# Display column names

# print(data.columns)

# print(data.value_counts())

# Extracting 'label' and 'text' columns from the 'data' DataFrame

labels = data['label']  # Contains the labels or categories associated with the text data
symptoms = data['text']  # Contains the textual data (e.g., symptoms, sentences) for analysis

# Text Preprocessing

stop_words = set(stopwords.words('english'))

# Apply preprocessing to symptoms

preprocessed_symptoms = symptoms.apply(preprocess_text)
# print(preprocessed_symptoms)

# Feature Extraction using TF-IDF

tfidf_vectorizer = TfidfVectorizer(max_features=1500)  # You can adjust max_features based on your dataset size
tfidf_features = tfidf_vectorizer.fit_transform(preprocessed_symptoms).toarray()
# print(f'{tfidf_vectorizer}\n\n{tfidf_features}')



# Split data into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(tfidf_features, labels, test_size=0.2, random_state=42)

# KNN Model Training

knn_classifier = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (k) based on your dataset
knn_classifier.fit(X_train, y_train)




# Predictions

predictions = knn_classifier.predict(X_test)



# Model Evaluation

accuracy = accuracy_score(y_test, predictions)
# print(f'Accuracy: {accuracy:.2f}')
# print(classification_report(y_test, predictions))


# Example Usage
symptom = input("Enter the symptoms separated by comma: ")

# Preprocess the input symptom
preprocessed_symptom = preprocess_text(symptom)

# Transform the preprocessed symptom using the same vectorizer used during training
symptom_tfidf = tfidf_vectorizer.transform([preprocessed_symptom])

# Predict the disease
predicted_disease = knn_classifier.predict(symptom_tfidf)
# print(preprocessed_symptom)
print(f'Predicted Disease: {predicted_disease[0]}')


# print(symptom_tfidf)

data = pd.read_csv('ayurvedic_symptoms_desc.csv')

words = symptom.split(", ")

data['common_words'] = data['English_Symptoms'].apply(lambda x: sum(word.lower() in x.lower() for word in words))


# Filter the data based on text similarity
filtered_data = data[data['common_words'] > 0]

# Sort the DataFrame based on the number of common words
filtered_data = filtered_data.sort_values(by='common_words', ascending=False)

# Drop the 'common_words' column as it's no longer needed
filtered_data = filtered_data.drop(columns=['common_words'])

original_data_same_indices = data.loc[filtered_data.index]

# Print or return the data
print(original_data_same_indices)
############################################################################################################################



import pandas as pd

def get_column_values(df, column_name):
    # Get the column values as a list
    column_values = df[column_name].tolist()

    # Convert the list to a string with space separation
    column_values_str = ' '.join(map(str, column_values))

    return column_values_str

df1 = pd.read_csv('Formulation-Indications.csv')

formulations_lst = list(df1['Name of Medicine'])

original_list = list(df1['Main Indications'])

processed_list = []

for item in original_list:
    # Remove spaces and newline characters, convert to lowercase
    processed_item = ''.join(item.split()).lower()
    processed_list.append(processed_item)

# print(processed_list[:5])

# List of lists of symptoms
list_of_symptoms = processed_list

# Flatten the list of lists and split the symptoms using commas and spaces
flat_symptoms = [symptom.replace(',', ' ').split() for symptoms in list_of_symptoms for symptom in symptoms.split(',')]

# Get unique symptoms as a list
unique_symptoms = list(set(symptom for sublist in flat_symptoms for symptom in sublist))

# Print the unique symptoms
# print(unique_symptoms[:5])

data = {
    "Formulation": formulations_lst,
    "Symptoms": processed_list,
}

# Create a DataFrame
df = pd.DataFrame(data)

symptoms = pd.read_csv('ayurvedic_symptoms_desc.csv')

symptoms['Symptom'] = symptoms['Symptom'].str.lower()

def symptoms_desc(symptom_name):
    row = symptoms[symptoms['Symptom'] == symptom_name.lower()]
#     print(row)
    if not row.empty:
        description = row.iloc[0]['Description']
        print(f'Description of "{symptom_name}": {description}')
    else:
        print(f'Symptom "{symptom_name}" not found in the DataFrame.')

def symptoms_lst_desc(user_symptoms):
    for item in user_symptoms:
#         print(item)
        symptoms_desc(item)

import difflib

# Your list of correct words (assuming you have a list called unique_symptoms)
correct_words = unique_symptoms

def correct_symptoms(symptoms):
    corrected_symptoms = []
    for symptom in symptoms:
        corrected_symptom = difflib.get_close_matches(symptom, correct_words, n=1, cutoff=0.6)
        if corrected_symptom:
            corrected_symptoms.append(corrected_symptom[0])
        else:
            corrected_symptoms.append(symptom)
    return corrected_symptoms

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

data = {
    "Formulation": formulations_lst,
    "Symptoms": processed_list,
}

df = pd.DataFrame(data)

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Transform the symptom text data into numerical features
X_tfidf = tfidf_vectorizer.fit_transform(df['Symptoms'])

# Create and train a classifier (e.g., Naive Bayes)
clf = MultinomialNB()
clf.fit(X_tfidf, df['Formulation'])

# Spelling Correction
user_input = get_column_values(original_data_same_indices, 'Symptom')
print(user_input)
input_symptoms = user_input.split()
new_symptoms = correct_symptoms(input_symptoms)
print(f"Did you mean: {', '.join(new_symptoms)}")

# Find Symptom Description
symptoms_lst_desc(new_symptoms)

# Predict Formulation 
new_symptoms_tfidf = tfidf_vectorizer.transform(new_symptoms)
predicted_label = clf.predict(new_symptoms_tfidf)
print(f"Predicted Formulation: {predicted_label[0]}")


### Create a boolean mask to filter rows where the second column matches any element in closest_formulations
mask = df1.iloc[:, 0].isin([predicted_label[0]])

# Use the mask to select the rows that match the condition
filtered_df = df1[mask]

# Iterate through the filtered DataFrame and print each row separately
for index, row in filtered_df.iterrows():
    print(row)
# Out:
# Enter the symptoms separated by comma:  High body temperature, pain, yellow urine, vomiting
# Predicted Disease: Jaundice
#            Symptom                      Description  \
# 219  Parinamashula                    Colicky pain.
# 220    Sarpadamsha                       Snakebite.
# 289      Aptantrak                       Snakebite.
# 153     Visavikara            Poisonous conditions.
# 10       Shulahara                 Pain management.
# ..             ...                              ...
# 100        Vatroga  Diseases related to Vata dosha.
# 97           Udara             Abdominal disorders.
# 96     Pittajvaram        Fever due to Pitta dosha.
# 95          Hridya                     Cardiotonic.
# 298      Mutraroga               Urinary disorders.
#
#                                       English_Symptoms  common_words
# 219  intermittent and crampy abdominal pain that co...             2
# 220  pain or swelling at the bite site, redness, br...             2
# 289  pain, swelling, puncture marks, nausea, vomiti...             2
# 153  Nausea,Vomiting,Abdominal Pain,Difficuly in br...             2
# 10   Colicky pain in the abdomen,Distention or bloa...             2
# ..                                                 ...           ...
# 100  joint pain,dry skin,constipation,gas and bloat...             1
# 97   debility, anorexia, indigestion, retention of ...             1
# 96                   headache,fever,vomiting,dizziness             1
# 95               chest pain,chest tightness,discomfort             1
# 298  Painful Urination,Frequent Urination,Difficult...             1
#
# [135 rows x 4 columns]
# Parinamashula Sarpadamsha Aptantrak Visavikara Shulahara Garavisha Amashula Urahkshata Udararoga Krimiroga Parinamshula Ashmari Vataroga Sharkara Krichhrartav Arshagarbhasayaroga Karnashula Drishtimandya Pittajashirahshula Krimi Sarvajvara Khanja Vatavikara Visarpa Vatashonita Hridroga Katishula Prameha Apachi Grahaniroga Yonivyapat Vataraktaruja Karnanada Shwetapradara Upadansha Amlapitta Kushta Bhrama Vatakaphajaroga Pramehapidika Gridhrasi Arsha Mutrasthila Paktishula Mutrashmari Visuchika Sandhigatvata Vriddhiroga Hritshula Raktatisara Bhagandara Striroga Pliha Raktajpravahika Shvetapradara Pama Angavedana Sandhishula Asthichyuti Sutikaroga Grahani Vandhyatva Vidagdhajirna Prishashula Sthaulya Trishna Grahaniroga?pravahika Janghashula Vranaropana Rajorodha Yonibhransha Raktapitta Praseka Pittajaroga Agnimandhya Atisara Gandamala Dagdhavrana Amvata Hrid-daurbalya Urdhvagaraktapitta Agnidagdha Sandhigatavata Granthi Ardhavbhedaka Vranashotha Bhagandar Raktarsha Dushtavrana Rajodushti Amavata Shirahshula Vidvibandha Yonishula Vishuchika Rajodosha Shirogatavata Vatarakta Arbuda Vrana Malavarodha Raktapradara Vishamajvara Netraroga Mukhapaka Karnasrava Karnagutha Pradara Netravrana Arochaka Vishmajvara Vandhyaroga Asthiruja Hanustambha Aksepa Apasmara Parshvashula Avabahuka Jara Raktanishthivana Halimaka Amatisara Manyastambha Jirnapratishaya Udarashula Ajirna Mutrakriccha Trikshula Kamala Shirokampa Vatroga Udara Pittajvaram Hridya Mutraroga
# Did you mean: parinamashula, sarpadamsha, aptantrak, visavikara, shulahara, garavisha, amashula, urahkshata, udararoga, krimiroga, parinamshula, ashmari, vataroga, sharkara, krichhrartav, arshagarbhasayaroga, karnashula, drishtimandya, pittajashirahshula, krimi, sarvajvara, khanja, vatavikara, visarpa, vatashonita, hridroga, katishula, prameha, apachi, grahaniroga, yonivyapat, vataraktaruja, karnanada, shwetapradara, upadansha, amlapitta, kushta, bhrama, vatakaphajaroga, pramehapidika, gridhrasi, arsha, mutrasthila, paktishula, mutrashmari, visuchika, sandhigatvata, vriddhiroga, hritshula, raktatisara, bhagandara, striroga, pliha, raktajpravahika, shvetapradara, ama, angavedana, sandhishula, asthichyuti, sutikaroga, grahani, vandhyatva, vidagdhajirna, prishashula, sthaulya, trishna, grahaniroga¸pravahika, janghashula, vranaropana, rajorodha, yonibhransha, raktapitta, praseka, pittajaroga, agnimandhya, atisara, gandamala, dagdhavrana, amvata, hrid-daurbalya, urdhvagaraktapitta, agnidagdha, sandhigatavata, granthi, ardhavbhedaka, vranashotha, bhagandar, raktarsha, dushtavrana, rajodushti, amavata, shirahshula, vidvibandha, yonishula, vishuchika, rajodosha, shirogatavata, vatarakta, arbuda, vrana, malavarodha, raktapradara, vishamajvara, netraroga, mukhapaka, karnasrava, karnagutha, pradara, netravrana, arochaka, vishmajvara, vandhyaroga, asthiruja, hanustambha, akshepa, apasmara, parshvashula, avabahuka, jara, raktanishthivana, halimaka, amatisara, manyastambha, jirnapratishaya, udarashula, ajirna, mutrakriccha, trikshula, kamala, shirokampa, vatroga, udara, pittajvara, hridya, mutraroga
# Description of "parinamashula": Colicky pain.
# Description of "sarpadamsha": Snakebite.
# Description of "aptantrak": Snakebite.
# Description of "visavikara": Poisonous conditions.
# Description of "shulahara": Pain management.
# Description of "garavisha": Poisoning by heavy metals.
# Description of "amashula": Abdominal colic due to Ama (toxins).
# Description of "urahkshata": Chest injury.
# Description of "udararoga": Abdominal disorders.
# Description of "krimiroga": Worm infestations.
# Description of "parinamshula": Colicky pain due to diet.
# Description of "ashmari": Kidney stones.
# Description of "vataroga": Diseases related to Vata dosha.
# Description of "sharkara": Pemphigus.
# Description of "krichhrartav": Painful menstruation.
# Description of "arshagarbhasayaroga": Hemorrhoids in pregnancy.
# Description of "karnashula": Ear pain.
# Description of "drishtimandya": Visual impairment.
# Description of "pittajashirahshula": Headache due to Pitta dosha.
# Description of "krimi": Worm infestations.
# Description of "sarvajvara": All types of fever.
# Description of "khanja": Lameness.
# Description of "vatavikara": Disorders related to the Vata dosha.
# Description of "visarpa": Erysipelas.
# Description of "vatashonita": Gouty arthritis with bleeding.
# Description of "hridroga": Heart disease.
# Description of "katishula": Backache.
# Description of "prameha": Urinary disorders.
# Description of "apachi": Herpes.
# Description of "grahaniroga": Irritable bowel syndrome.
# Description of "yonivyapat": Vaginal prolapse.
# Description of "vataraktaruja": Gout.
# Description of "karnanada": Earache.
# Description of "shwetapradara": White discharge (leucorrhea).
# Description of "upadansha": Skin eruptions.
# Description of "amlapitta": Hyperacidity.
# Description of "kushta": Skin disorders.
# Description of "bhrama": Vertigo.
# Description of "vatakaphajaroga": Diseases related to Vata and Kapha dosha.
# Description of "pramehapidika": Boils in urinary tract disorders.
# Description of "gridhrasi": Sciatica.
# Description of "arsha": Hemorrhoids.
# Description of "mutrasthila": Urinary retention.
# Description of "paktishula": Colicky pain due to digestion.
# Description of "mutrashmari": Kidney stones.
# Description of "visuchika": Dysentery.
# Description of "sandhigatvata": Joint disorders due to Vata dosha.
# Description of "vriddhiroga": Aging-related diseases.
# Description of "hritshula": Chest pain.
# Description of "raktatisara": Blood diarrhea.
# Description of "bhagandara": Fistula-in-ano.
# Description of "striroga": Gynecological disorders.
# Description of "pliha": Spleen disorders.
# Description of "raktajpravahika": Hemorrhagic diarrhea.
# Description of "shvetapradara": White discharge (leucorrhea).
# Description of "ama": Toxins or undigested food.
# Description of "angavedana": Body pain.
# Description of "sandhishula": Joint pain.
# Description of "asthichyuti": Bone atrophy.
# Description of "sutikaroga": Postpartum disorders.
# Description of "grahani": Irritable bowel syndrome.
# Description of "vandhyatva": Infertility.
# Description of "vidagdhajirna": Digestive disorders causing burning sensation.
# Description of "prishashula": Side pain.
# Description of "sthaulya": Obesity.
# Description of "trishna": Thirst.
# Symptom "grahaniroga¸pravahika" not found in the DataFrame.
# Description of "janghashula": Calf pain.
# Description of "vranaropana": Wound healing.
# Description of "rajorodha": Menstrual blockage.
# Description of "yonibhransha": Vaginal prolapse.
# Description of "raktapitta": Bleeding disorders related to Pitta dosha.
# Description of "praseka": Excessive salivation.
# Description of "pittajaroga": Diseases related to Pitta dosha.
# Description of "agnimandhya": Digestive weakness.
# Description of "atisara": Diarrhea.
# Description of "gandamala": Tonsillitis.
# Description of "dagdhavrana": Burn wounds.
# Description of "amvata": Rheumatism.
# Description of "hrid-daurbalya": Weakness of the heart.
# Description of "urdhvagaraktapitta": Upper gastrointestinal bleeding.
# Description of "agnidagdha": Burnt by digestive fire (related to digestion).
# Description of "sandhigatavata": Osteoarthritis.
# Description of "granthi": Cyst or tumor.
# Description of "ardhavbhedaka": Migraine.
# Description of "vranashotha": Swelling of wounds.
# Description of "bhagandar": Fistula-in-ano.
# Description of "raktarsha": Hemorrhoids.
# Description of "dushtavrana": Infected wounds.
# Description of "rajodushti": Menstrual disorders.
# Description of "amavata": Rheumatoid arthritis.
# Description of "shirahshula": Headache.
# Description of "vidvibandha": Constipation due to neurological causes.
# Description of "yonishula": Pelvic pain.
# Description of "vishuchika": Dysentery.
# Description of "rajodosha": Menstrual disorders.
# Description of "shirogatavata": Headache due to Vata imbalance.
# Description of "vatarakta": Gout.
# Description of "arbuda": Tumors or growths.
# Description of "vrana": Wounds or injuries.
# Description of "malavarodha": Constipation.
# Description of "raktapradara": Menorrhagia (excessive menstrual bleeding).
# Description of "vishamajvara": Irregular fever.
# Description of "netraroga": Eye disorders.
# Description of "mukhapaka": Oral ulcers.
# Description of "karnasrava": Ear discharge.
# Description of "karnagutha": Ear infection.
# Description of "pradara": Leucorrhea.
# Description of "netravrana": Eye injury.
# Description of "arochaka": Loss of appetite.
# Description of "vishmajvara": Poisonous fever.
# Description of "vandhyaroga": Infertility.
# Description of "asthiruja": Joint pain.
# Description of "hanustambha": Facial paralysis.
# Symptom "akshepa" not found in the DataFrame.
# Description of "apasmara": Epilepsy.
# Description of "parshvashula": Side pain.
# Description of "avabahuka": Frozen shoulder.
# Description of "jara": Aging.
# Description of "raktanishthivana": Blood vessel disorders.
# Description of "halimaka": Cirrhosis of the liver.
# Description of "amatisara": Chronic diarrhea.
# Description of "manyastambha": Muscle stiffness.
# Description of "jirnapratishaya": Chronic rhinitis.
# Description of "udarashula": Abdominal pain.
# Description of "ajirna": Indigestion.
# Description of "mutrakriccha": Difficulty in urination.
# Description of "trikshula": Abdominal colic.
# Description of "kamala": Jaundice.
# Description of "shirokampa": Tremors of the head.
# Description of "vatroga": Diseases related to Vata dosha.
# Description of "udara": Abdominal disorders.
# Symptom "pittajvara" not found in the DataFrame.
# Description of "hridya": Cardiotonic.
# Description of "mutraroga": Urinary disorders.
# Predicted Formulation: Kapardika Bhasma
# Name of Medicine                                                 Kapardika Bhasma
# Reference text                                                                AFI
# Dispensing Pack Size                                                         5 gm
# Main Indications                            Parinamashula, Agnimandya, Karnasrava
# Dose                                                                       250 mg
# Precaution/ Contraindication    Not to be used on change of physical\ncharacte...
# Preferred use (OPD/ IPD)                                                     Both
# Class                                                                           Q
# Name: 178, dtype: object

# %%
import pandas as pd

def get_column_values(df, column_name):
    # Get the column values as a list
    column_values = df[column_name].tolist()

    # Convert the list to a string with space separation
    column_values_str = ' '.join(map(str, column_values))

    return column_values_str

df1 = pd.read_csv('Formulation-Indications.csv')

formulations_lst = list(df1['Name of Medicine'])

original_list = list(df1['Main Indications'])

processed_list = []

for item in original_list:
    # Remove spaces and newline characters, convert to lowercase
    processed_item = ''.join(item.split()).lower()
    processed_list.append(processed_item)

# print(processed_list[:5])

# List of lists of symptoms
list_of_symptoms = processed_list

# Flatten the list of lists and split the symptoms using commas and spaces
flat_symptoms = [symptom.replace(',', ' ').split() for symptoms in list_of_symptoms for symptom in symptoms.split(',')]

# Get unique symptoms as a list
unique_symptoms = list(set(symptom for sublist in flat_symptoms for symptom in sublist))

# Print the unique symptoms
# print(unique_symptoms[:5])

data = {
    "Formulation": formulations_lst,
    "Symptoms": processed_list,
}

# Create a DataFrame
df = pd.DataFrame(data)

symptoms = pd.read_csv('ayurvedic_symptoms_desc.csv')

symptoms['Symptom'] = symptoms['Symptom'].str.lower()

def symptoms_desc(symptom_name):
    row = symptoms[symptoms['Symptom'] == symptom_name.lower()]
#     print(row)
    if not row.empty:
        description = row.iloc[0]['Description']
        print(f'Description of "{symptom_name}": {description}')
    else:
        print(f'Symptom "{symptom_name}" not found in the DataFrame.')

def symptoms_lst_desc(user_symptoms):
    for item in user_symptoms:
#         print(item)
        symptoms_desc(item)

import difflib

# Your list of correct words (assuming you have a list called unique_symptoms)
correct_words = unique_symptoms

def correct_symptoms(symptoms):
    corrected_symptoms = []
    for symptom in symptoms:
        corrected_symptom = difflib.get_close_matches(symptom, correct_words, n=1, cutoff=0.6)
        if corrected_symptom:
            corrected_symptoms.append(corrected_symptom[0])
        else:
            corrected_symptoms.append(symptom)
    return corrected_symptoms

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

data = {
    "Formulation": formulations_lst,
    "Symptoms": processed_list,
}

df = pd.DataFrame(data)

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Transform the symptom text data into numerical features
X_tfidf = tfidf_vectorizer.fit_transform(df['Symptoms'])

# Create and train a classifier (e.g., Naive Bayes)
clf = MultinomialNB()
clf.fit(X_tfidf, df['Formulation'])

# Spelling Correction
user_input = get_column_values(original_data_same_indices, 'Symptom')
print(user_input)
input_symptoms = user_input.split()
new_symptoms = correct_symptoms(input_symptoms)
print(f"Did you mean: {', '.join(new_symptoms)}")

# Find Symptom Description
symptoms_lst_desc(new_symptoms)

# Predict Formulation 
new_symptoms_tfidf = tfidf_vectorizer.transform(new_symptoms)
predicted_label = clf.predict(new_symptoms_tfidf)
print(f"Predicted Formulation: {predicted_label[0]}")


### Create a boolean mask to filter rows where the second column matches any element in closest_formulations
mask = df1.iloc[:, 0].isin([predicted_label[0]])

# Use the mask to select the rows that match the condition
filtered_df = df1[mask]

# Iterate through the filtered DataFrame and print each row separately
for index, row in filtered_df.iterrows():
    print(row)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
# from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


# Text Preprocessing Function

def preprocess_text(text):
    # Tokenization
    words = word_tokenize(text.lower())
    # Removing stopwords and non-alphabetic characters
    words = [word for word in words if word.isalpha() and word not in stop_words]
    return ' '.join(words)


# Load the dataset

data = pd.read_csv('Symptom2Disease.csv') 

# Displaying the dataset

# print(data)

data.drop(columns=["Unnamed: 0"], inplace=True)

# Concise summary of DataFrame

# print(data.info())

# Check for null values

# print(data.isnull().sum())

# Display column names

# print(data.columns)

# print(data.value_counts())

# Extracting 'label' and 'text' columns from the 'data' DataFrame

labels = data['label']  # Contains the labels or categories associated with the text data
symptoms = data['text']  # Contains the textual data (e.g., symptoms, sentences) for analysis

# Text Preprocessing

stop_words = set(stopwords.words('english'))

# Apply preprocessing to symptoms

preprocessed_symptoms = symptoms.apply(preprocess_text)
# print(preprocessed_symptoms)

# Feature Extraction using TF-IDF

tfidf_vectorizer = TfidfVectorizer(max_features=1500)  # You can adjust max_features based on your dataset size
tfidf_features = tfidf_vectorizer.fit_transform(preprocessed_symptoms).toarray()
# print(f'{tfidf_vectorizer}\n\n{tfidf_features}')



# Split data into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(tfidf_features, labels, test_size=0.2, random_state=42)

# KNN Model Training

knn_classifier = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (k) based on your dataset
knn_classifier.fit(X_train, y_train)




# Predictions

predictions = knn_classifier.predict(X_test)



# Model Evaluation

accuracy = accuracy_score(y_test, predictions)
# print(f'Accuracy: {accuracy:.2f}')
# print(classification_report(y_test, predictions))


# Example Usage
symptom = input("Enter the symptoms separated by comma: ")

# Preprocess the input symptom
preprocessed_symptom = preprocess_text(symptom)

# Transform the preprocessed symptom using the same vectorizer used during training
symptom_tfidf = tfidf_vectorizer.transform([preprocessed_symptom])

# Predict the disease
predicted_disease = knn_classifier.predict(symptom_tfidf)
# print(preprocessed_symptom)
print(f'Predicted Disease: {predicted_disease[0]}')


# print(symptom_tfidf)

data = pd.read_csv('ayurvedic_symptoms_desc.csv')

words = symptom.split(", ")

# Filter the data based on text similarity
filtered_data = data[data['English_Symptoms'].apply(lambda x: any(word.lower() in x.lower() for word in words))]

original_data_same_indices = data.loc[filtered_data.index]

# Print or return the data
print(original_data_same_indices)
# Out:
# Enter the symptoms separated by comma: print(original_data_same_indices)
# Predicted Disease: Bronchial Asthma
# Empty DataFrame
# Columns: [Symptom, Description, English_Symptoms]
# Index: []

# %%
df1
# Out:
#                   Name of Medicine Reference text Dispensing Pack Size  \
# 0                     Abhayarishta            AFI               200 ml
# 1                     Amritarishta            AFI               200 ml
# 2                  Aragvadharishta             AH                200ml
# 3                     Aravindasava            AFI               200 ml
# 4    Arjunarishta/ Parthadyarishta            AFI               200 ml
# ..                             ...            ...                  ...
# 197            Tribhuvankirti Rasa            AFI                 5 gm
# 198            Vatagajankusha Rasa             BR                 5 gm
# 199           Vatavidhavansan Rasa            AFI                 5 gm
# 200                 Navayasa Lauha            AFI                 5 gm
# 201               Saptamrita Lauha            AFI                 5 gm
#
#                                       Main Indications        Dose  \
# 0              Arsha, Agnimandya,\nUdararoga, Vibandha  12 - 24 ml
# 1                              SarvaJvara, Jirna Jvara  12 - 24 ml
# 2                        Kandu, Tvak Vikara,\nVibandha  12 - 24 ml
# 3            Balaroga, Balakshaya,\nAgnimandya, Aruchi  12 - 24 ml
# 4    Hridroga, Hriddrava, Hrid- daurbalya, Moha,\nM...  12 - 24 ml
# ..                                                 ...         ...
# 197                           Jvara, Pratishyaya, Kasa  125-250 mg
# 198  Vata Roga, Avabahuka, Urustambha, Pakshaghata,...      250 mg
# 199              Vatajashula, Sutika Vata, Grahaniroga      250 mg
# 200                           Pandu, Kamala,\nHridroga      250 mg
# 201                              Timira, Drishtimandya      250 mg
#
#                           Precaution/ Contraindication  \
# 0                                                   NS
# 1                                                   NS
# 2                                                   NS
# 3                                                   NS
# 4                                                   NS
# ..                                                 ...
# 197  Bradycar dia, arrhythm ias, small children, Vr...
# 198  Long term use, Vrikka Roga, peri- concepti ona...
# 199                                                 NS
# 200                                                 NS
# 201                                                 NS
#
#     Preferred use (OPD/ IPD) Class
# 0                       Both     A
# 1                       Both     A
# 2                       Both     A
# 3                       Both     A
# 4                       Both     A
# ..                       ...   ...
# 197                     Both     S
# 198                      IPD     S
# 199                      IPD     S
# 200                     Both     T
# 201                     Both     T
#
# [202 rows x 8 columns]

# %%
import pandas as pd

def get_column_values(df, column_name):
    # Get the column values as a list
    column_values = df[column_name].tolist()

    # Convert the list to a string with space separation
    column_values_str = ' '.join(map(str, column_values))

    return column_values_str

df1 = pd.read_csv('Formulation-Indications.csv')

formulations_lst = list(df1['Name of Medicine'])

original_list = list(df1['Main Indications'])

processed_list = []

for item in original_list:
    # Remove spaces and newline characters, convert to lowercase
    processed_item = ''.join(item.split()).lower()
    processed_list.append(processed_item)

# print(processed_list[:5])

# List of lists of symptoms
list_of_symptoms = processed_list

# Flatten the list of lists and split the symptoms using commas and spaces
flat_symptoms = [symptom.replace(',', ' ').split() for symptoms in list_of_symptoms for symptom in symptoms.split(',')]

# Get unique symptoms as a list
unique_symptoms = list(set(symptom for sublist in flat_symptoms for symptom in sublist))

# Print the unique symptoms
# print(unique_symptoms[:5])

data = {
    "Formulation": formulations_lst,
    "Symptoms": processed_list,
}

# Create a DataFrame
df = pd.DataFrame(data)

symptoms = pd.read_csv('ayurvedic_symptoms_desc.csv')

symptoms['Symptom'] = symptoms['Symptom'].str.lower()

def symptoms_desc(symptom_name):
    row = symptoms[symptoms['Symptom'] == symptom_name.lower()]
#     print(row)
    if not row.empty:
        description = row.iloc[0]['Description']
        print(f'Description of "{symptom_name}": {description}')
    else:
        print(f'Symptom "{symptom_name}" not found in the DataFrame.')

def symptoms_lst_desc(user_symptoms):
    for item in user_symptoms:
#         print(item)
        symptoms_desc(item)

import difflib

# Your list of correct words (assuming you have a list called unique_symptoms)
correct_words = unique_symptoms

def correct_symptoms(symptoms):
    corrected_symptoms = []
    for symptom in symptoms:
        corrected_symptom = difflib.get_close_matches(symptom, correct_words, n=1, cutoff=0.6)
        if corrected_symptom:
            corrected_symptoms.append(corrected_symptom[0])
        else:
            corrected_symptoms.append(symptom)
    return corrected_symptoms

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

data = {
    "Formulation": formulations_lst,
    "Symptoms": processed_list,
}

df = pd.DataFrame(data)

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Transform the symptom text data into numerical features
X_tfidf = tfidf_vectorizer.fit_transform(df['Symptoms'])

# Create and train a classifier (e.g., Naive Bayes)
clf = MultinomialNB()
clf.fit(X_tfidf, df['Formulation'])

# Spelling Correction
user_input = get_column_values(original_data_same_indices, 'Symptom')
print(user_input)
input_symptoms = user_input.split()
new_symptoms = correct_symptoms(input_symptoms)
print(f"Did you mean: {', '.join(new_symptoms)}")

# Find Symptom Description
symptoms_lst_desc(new_symptoms)

# Predict Formulation 
new_symptoms_tfidf = tfidf_vectorizer.transform(new_symptoms)
predicted_label = clf.predict(new_symptoms_tfidf)
print(f"Predicted Formulation: {predicted_label[0]}")
# Out:
# Jvara
# Did you mean: jvara
# Description of "jvara": Fever.
# Predicted Formulation: Punarnavadi Kashayam

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
# from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


# Text Preprocessing Function

def preprocess_text(text):
    # Tokenization
    words = word_tokenize(text.lower())
    # Removing stopwords and non-alphabetic characters
    words = [word for word in words if word.isalpha() and word not in stop_words]
    return ' '.join(words)


# Load the dataset

data = pd.read_csv('Symptom2Disease.csv')

# Displaying the dataset

# print(data)

data.drop(columns=["Unnamed: 0"], inplace=True)

# Concise summary of DataFrame

# print(data.info())

# Check for null values

# print(data.isnull().sum())

# Display column names

# print(data.columns)

# print(data.value_counts())

# Extracting 'label' and 'text' columns from the 'data' DataFrame

labels = data['label']  # Contains the labels or categories associated with the text data
symptoms = data['text']  # Contains the textual data (e.g., symptoms, sentences) for analysis

# Text Preprocessing

stop_words = set(stopwords.words('english'))

# Apply preprocessing to symptoms

preprocessed_symptoms = symptoms.apply(preprocess_text)
# print(preprocessed_symptoms)

# Feature Extraction using TF-IDF

tfidf_vectorizer = TfidfVectorizer(max_features=2000)  # You can adjust max_features based on your dataset size
tfidf_features = tfidf_vectorizer.fit_transform(preprocessed_symptoms).toarray()
# print(f'{tfidf_vectorizer}\n\n{tfidf_features}')



# Split data into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(tfidf_features, labels, test_size=0.2, random_state=42)

# KNN Model Training

knn_classifier = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (k) based on your dataset
knn_classifier.fit(X_train, y_train)




# Predictions

predictions = knn_classifier.predict(X_test)



# Model Evaluation

accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy:.2f}')
print(classification_report(y_test, predictions))


# Example Usage
symptom = input("Enter the symptoms separated by comma: ")

# Preprocess the input symptom
preprocessed_symptom = preprocess_text(symptom)

# Transform the preprocessed symptom using the same vectorizer used during training
symptom_tfidf = tfidf_vectorizer.transform([preprocessed_symptom])

# Predict the disease
predicted_disease = knn_classifier.predict(symptom_tfidf)
# print(preprocessed_symptom)
print(f'Predicted Disease: {predicted_disease[0]}')


# print(symptom_tfidf)

data = pd.read_csv('ayurvedic_symptoms_desc_updated.csv')

words = symptom.split(",")

data['common_words'] = data['English_Symptoms'].apply(lambda x: sum(word.lower() in x.lower() for word in words))


# Filter the data based on text similarity
filtered_data = data[data['common_words'] > 0]

# Sort the DataFrame based on the number of common words
filtered_data = filtered_data.sort_values(by='common_words', ascending=False)

# Drop the 'common_words' column as it's no longer needed
filtered_data = filtered_data.drop(columns=['common_words'])

original_data_same_indices = data.loc[filtered_data.index]

# Print or return the data
print(original_data_same_indices)
############################################################################################################################
original_data_same_indices = original_data_same_indices.head(10)


import pandas as pd

def get_column_values(df, column_name):
    # Get the column values as a list
    column_values = df[column_name].tolist()

    # Convert the list to a string with space separation
    column_values_str = ' '.join(map(str, column_values))

    return column_values_str

df1 = pd.read_csv('Formulation-Indications.csv')

formulations_lst = list(df1['Name of Medicine'])

original_list = list(df1['Main Indications'])

processed_list = []

for item in original_list:
    # Remove spaces and newline characters, convert to lowercase
    processed_item = ''.join(item.split()).lower()
    processed_list.append(processed_item)

# print(processed_list[:5])

# List of lists of symptoms
list_of_symptoms = processed_list

# Flatten the list of lists and split the symptoms using commas and spaces
flat_symptoms = [symptom.replace(',', ' ').split() for symptoms in list_of_symptoms for symptom in symptoms.split(',')]

# Get unique symptoms as a list
unique_symptoms = list(set(symptom for sublist in flat_symptoms for symptom in sublist))

# Print the unique symptoms
# print(unique_symptoms[:5])

data = {
    "Formulation": formulations_lst,
    "Symptoms": processed_list,
}

# Create a DataFrame
df = pd.DataFrame(data)

symptoms = pd.read_csv('ayurvedic_symptoms_desc_updated.csv')

symptoms['Symptom'] = symptoms['Symptom'].str.lower()

def symptoms_desc(symptom_name):
    row = symptoms[symptoms['Symptom'] == symptom_name.lower()]
#     print(row)
    if not row.empty:
        description = row.iloc[0]['Description']
        print(f'Description of "{symptom_name}": {description}')
    else:
        print(f'Symptom "{symptom_name}" not found in the DataFrame.')

def symptoms_lst_desc(user_symptoms):
    for item in user_symptoms:
#         print(item)
        symptoms_desc(item)

import difflib

# Your list of correct words (assuming you have a list called unique_symptoms)
correct_words = unique_symptoms

def correct_symptoms(symptoms):
    corrected_symptoms = []
    for symptom in symptoms:
        corrected_symptom = difflib.get_close_matches(symptom, correct_words, n=1, cutoff=0.6)
        if corrected_symptom:
            corrected_symptoms.append(corrected_symptom[0])
        else:
            corrected_symptoms.append(symptom)
    return corrected_symptoms

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

data = {
    "Formulation": formulations_lst,
    "Symptoms": processed_list,
}

df = pd.DataFrame(data)

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Transform the symptom text data into numerical features
X_tfidf = tfidf_vectorizer.fit_transform(df['Symptoms'])

# Create and train a classifier (e.g., Naive Bayes)
clf = MultinomialNB()
clf.fit(X_tfidf, df['Formulation'])

# Spelling Correction
user_input = get_column_values(original_data_same_indices, 'Symptom')
print(user_input)
input_symptoms = user_input.split()
new_symptoms = correct_symptoms(input_symptoms)
print(f"Did you mean: {', '.join(new_symptoms)}")

# Find Symptom Description
symptoms_lst_desc(new_symptoms)

# Predict Formulation
new_symptoms_tfidf = tfidf_vectorizer.transform(new_symptoms)
predicted_label = clf.predict(new_symptoms_tfidf)
print(f"Predicted Formulation: {predicted_label[0]}")

c = len(original_data_same_indices) if len(original_data_same_indices)<10 else 10

while (c>0):
  print("*"*50)
  ### Create a boolean mask to filter rows where the second column matches any element in closest_formulations
  mask = df1.iloc[:, 0].isin([predicted_label[len(original_data_same_indices)-c]])

  # Use the mask to select the rows that match the condition
  filtered_df = df1[mask]

  # Iterate through the filtered DataFrame and print each row separately
  for index, row in filtered_df.iterrows():
      print(row)
  print("*"*50)
  c-=1
# Out:
# Accuracy: 0.95
#                                  precision    recall  f1-score   support
#
#                            Acne       0.88      1.00      0.93         7
#                       Arthritis       1.00      1.00      1.00        10
#                Bronchial Asthma       0.85      1.00      0.92        11
#            Cervical spondylosis       1.00      1.00      1.00         7
#                     Chicken pox       0.80      1.00      0.89        12
#                     Common Cold       1.00      0.83      0.91        12
#                          Dengue       0.92      0.92      0.92        12
#           Dimorphic Hemorrhoids       1.00      1.00      1.00         7
#                Fungal infection       1.00      1.00      1.00        13
#                    Hypertension       1.00      1.00      1.00        10
#                        Impetigo       1.00      1.00      1.00        11
#                        Jaundice       1.00      1.00      1.00        11
#                         Malaria       0.92      1.00      0.96        11
#                        Migraine       1.00      1.00      1.00        10
#                       Pneumonia       1.00      1.00      1.00        11
#                       Psoriasis       1.00      0.50      0.67         6
#                         Typhoid       1.00      0.89      0.94         9
#                  Varicose Veins       1.00      0.92      0.96        12
#                         allergy       0.92      1.00      0.96        12
#                        diabetes       1.00      1.00      1.00         8
#                   drug reaction       1.00      0.80      0.89         5
# gastroesophageal reflux disease       0.92      1.00      0.96        11
#            peptic ulcer disease       0.90      0.82      0.86        11
#         urinary tract infection       1.00      1.00      1.00        11
#
#                        accuracy                           0.95       240
#                       macro avg       0.96      0.94      0.95       240
#                    weighted avg       0.96      0.95      0.95       240
# Enter the symptoms separated by comma:  high_body_temperature,pain,vomiting,acne,bodyache,headache
# Predicted Disease: Malaria
#           Symptom                 Description  \
# 153    Visavikara       Poisonous conditions.
# 274     Krimiroga          Worm infestations.
# 162     Garavisha  Poisoning by heavy metals.
# 147   Vishmajvara            Poisonous fever.
# 142   Vandhyaroga                Infertility.
# ..            ...                         ...
# 97          Udara        Abdominal disorders.
# 95         Hridya                Cardiotonic.
# 94      Mukhapaka                Oral ulcers.
# 90   Vishamajvara            Irregular fever.
# 298     Mutraroga          Urinary disorders.
#
#                                       English_Symptoms  common_words
# 153  Nausea,Vomiting,Abdominal_Pain,Difficuly_in_br...             2
# 274  Abdominal_Pain,Diarrhea,Constipation,Nausea_an...             2
# 162  nausea,vomiting,abdominal_pain,fatigue,neurolo...             2
# 147  pain_in_smaller_joints,excessive_sleep,heavine...             2
# 142             nausea,headache,dizziness,and_vomiting             2
# ..                                                 ...           ...
# 97   debility,anorexia,indigestion,retention_of_uri...             1
# 95               chest_pain,chest_tightness,discomfort             1
# 94   Burning_pain,Difficult_to_engulfed_the_food,re...             1
# 90   pain_in_smaller_joints,excessive_sleep,heavine...             1
# 298  Painful_Urination,Frequent_Urination,Difficult...             1
#
# [146 rows x 4 columns]
# Visavikara Krimiroga Garavisha Vishmajvara Vandhyaroga Amashula Krichhrartav Ajirna Udararoga Pittajvaram
# Did you mean: visavikara, krimiroga, garavisha, vishmajvara, vandhyaroga, amashula, krichhrartav, ajirna, udararoga, pittajvara
# Description of "visavikara": Poisonous conditions.
# Description of "krimiroga": Worm infestations.
# Description of "garavisha": Poisoning by heavy metals.
# Description of "vishmajvara": Poisonous fever.
# Description of "vandhyaroga": Infertility.
# Description of "amashula": Abdominal colic due to Ama (toxins).
# Description of "krichhrartav": Painful menstruation.
# Description of "ajirna": Indigestion.
# Description of "udararoga": Abdominal disorders.
# Symptom "pittajvara" not found in the DataFrame.
# Predicted Formulation: Kalyanaka Ghrita
# **************************************************
# Name of Medicine                                                 Kalyanaka Ghrita
# Reference text                                                                AFI
# Dispensing Pack Size                                                       100 gm
# Main Indications                Bhutonmada, Apsmara,Balagraha, Visavikara, Gar...
# Dose                                                                     10-15 gm
# Precaution/ Contraindication                                                   NS
# Preferred use (OPD/ IPD)                                                      IPD
# Class                                                                           F
# Name: 77, dtype: object
# **************************************************
# **************************************************
# Name of Medicine                                    Vidanga Churna
# Reference text                                                 API
# Dispensing Pack Size                                         50 gm
# Main Indications                               Krimiroga, Medoroga
# Dose                                                      5-10  gm
# Precaution/ Contraindication    May prevent or disrupt\nconception
# Preferred use (OPD/ IPD)                                      Both
# Class                                                            H
# Name: 115, dtype: object
# **************************************************
# **************************************************
# Name of Medicine                                                 Kalyanaka Ghrita
# Reference text                                                                AFI
# Dispensing Pack Size                                                       100 gm
# Main Indications                Bhutonmada, Apsmara,Balagraha, Visavikara, Gar...
# Dose                                                                     10-15 gm
# Precaution/ Contraindication                                                   NS
# Preferred use (OPD/ IPD)                                                      IPD
# Class                                                                           F
# Name: 77, dtype: object
# **************************************************
# **************************************************
# Name of Medicine                   Samshamani Vati\n/ Guduchighana Vati
# Reference text                                                      AFI
# Dispensing Pack Size                                               5 gm
# Main Indications                Jvara, Jirna Jvara,\nVishma Jvara, Daha
# Dose                                                         250-500 mg
# Precaution/ Contraindication                                         NS
# Preferred use (OPD/ IPD)                                           Both
# Class                                                                 L
# Name: 165, dtype: object
# **************************************************
# **************************************************
# Name of Medicine                                         Puga Khanda/ Supari Paka
# Reference text                                                                AFI
# Dispensing Pack Size                                                      100\ngm
# Main Indications                Vandhyaroga, Pradara, Somaroga, Garbhadosha,\n...
# Dose                                                                      6-12 gm
# Precaution/ Contraindication                                                   NS
# Preferred use (OPD/ IPD)                                                     Both
# Class                                                                           C
# Name: 40, dtype: object
# **************************************************
# **************************************************
# Name of Medicine                          Dhanyapanchaka\nKashaya Churna
# Reference text                                                       AFI
# Dispensing Pack Size                                             100\ngm
# Main Indications                Amashula, Amatisara,\nAgnimandya, Aruchi
# Dose                                                            25-50 ml
# Precaution/ Contraindication                                          NS
# Preferred use (OPD/ IPD)                                            Both
# Class                                                                  D
# Name: 49, dtype: object
# **************************************************
# **************************************************
# Name of Medicine                                                      Kumaryasava
# Reference text                                                                AFI
# Dispensing Pack Size                                                       200 ml
# Main Indications                Rajodushti, Krichhrartav, Paktishula,\nParinam...
# Dose                                                                   12 - 24 ml
# Precaution/ Contraindication                                                   NS
# Preferred use (OPD/ IPD)                                                     Both
# Class                                                                           A
# Name: 14, dtype: object
# **************************************************
# **************************************************
# Name of Medicine                                                   Lahsunadi Vati
# Reference text                                                                AFI
# Dispensing Pack Size                                                        10 gm
# Main Indications                                       Visuchika, Ajirna, Atisara
# Dose                                                                 500 mg -1 gm
# Precaution/ Contraindication    Hyperacidity, Peptic Ulcer, Pitta Prakriti, hi...
# Preferred use (OPD/ IPD)                                                     Both
# Class                                                                           L
# Name: 162, dtype: object
# **************************************************
# **************************************************
# Name of Medicine                                                  Haritaki Churna
# Reference text                                                                API
# Dispensing Pack Size                                                        50 gm
# Main Indications                                              Vibandha, Udararoga
# Dose                                                                       3-6 gm
# Precaution/ Contraindication    Debility, pregnancy, dehydration\n, Paittika R...
# Preferred use (OPD/ IPD)                                                     Both
# Class                                                                           H
# Name: 108, dtype: object
# **************************************************
# **************************************************
# Name of Medicine                                                   Godanti Bhasma
# Reference text                                                                AFI
# Dispensing Pack Size                                                        10 gm
# Main Indications                       Shirahshula, Pitta Jvara, Jirnajvara, Daha
# Dose                            500 mg- 1 gm  with ghee, sugar, warm\nmilk or ...
# Precaution/ Contraindication                                                   NS
# Preferred use (OPD/ IPD)                                                     Both
# Class                                                                           Q
# Name: 176, dtype: object
# **************************************************

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

def preprocess_text(text):
    words = word_tokenize(text.lower())
    words = [word for word in words if word.isalpha() and word not in stop_words]
    return ' '.join(words)

data = pd.read_csv('Symptom2Disease.csv') 
data.drop(columns=["Unnamed: 0"], inplace=True)
labels = data['label']  
symptoms = data['text']  

stop_words = set(stopwords.words('english'))
preprocessed_symptoms = symptoms.apply(preprocess_text)

tfidf_vectorizer = TfidfVectorizer(max_features=1500)  
tfidf_features = tfidf_vectorizer.fit_transform(preprocessed_symptoms).toarray()

X_train, X_test, y_train, y_test = train_test_split(tfidf_features, labels, test_size=0.2, random_state=42)

knn_classifier = KNeighborsClassifier(n_neighbors=5)  
knn_classifier.fit(X_train, y_train)

predictions = knn_classifier.predict(X_test)

accuracy = accuracy_score(y_test, predictions)

symptom = input("Enter the symptoms separated by comma: ")
preprocessed_symptom = preprocess_text(symptom)
symptom_tfidf = tfidf_vectorizer.transform([preprocessed_symptom])
predicted_disease = knn_classifier.predict(symptom_tfidf)
print(f'Predicted Disease: {predicted_disease[0]}')

data = pd.read_csv('ayurvedic_symptoms_desc.csv')
words = symptom.split(", ")
data['common_words'] = data['English_Symptoms'].apply(lambda x: sum(word.lower() in x.lower() for word in words))
filtered_data = data[data['common_words'] > 0]
filtered_data = filtered_data.sort_values(by='common_words', ascending=False)
filtered_data = filtered_data.drop(columns=['common_words'])
original_data_same_indices = data.loc[filtered_data.index]
print(original_data_same_indices)
# Out:
# Enter the symptoms separated by comma: fever, diarrhea, malnutrition, respiratory infections.
# Predicted Disease: Typhoid
#                    Symptom                                     Description  \
# 37                Balaroga                             Pediatric diseases.
# 291            Jvaratisara                              Febrile dysentery.
# 235               Vidradhi                                        Abscess.
# 198               Amashula            Abdominal colic due to Ama (toxins).
# 212                  Krimi                              Worm infestations.
# 214             Jirnajvara                                  Chronic fever.
# 217             Sarvajvara                             All types of fever.
# 224  Grahaniroga?pravahika         Irritable bowel syndrome with diarrhea.
# 234          Vidagdhajirna  Digestive disorders causing burning sensation.
# 252                   Pama                                     Filariasis.
# 176            Grahaniroga                       Irritable bowel syndrome.
# 255        Raktajpravahika                           Hemorrhagic diarrhea.
# 273            Raktatisara                                 Blood diarrhea.
# 274              Krimiroga                              Worm infestations.
# 280              Visuchika                                      Dysentery.
# 287            Mutrasthila                              Urinary retention.
# 189                Visarpa                                     Erysipelas.
# 3              Sutikadosha                           Postpartum disorders.
# 15              Vishuchika                                      Dysentery.
# 146                  Gulma                        Abdominal tumor or mass.
# 120       Raktanishthivana                         Blood vessel disorders.
# 110                 Ajirna                                    Indigestion.
# 96             Pittajvaram                       Fever due to Pitta dosha.
# 94               Mukhapaka                                    Oral ulcers.
# 88              Raktapitta      Bleeding disorders related to Pitta dosha.
# 86                    Daha                              Burning sensation.
# 85             Rajayakshma                                   Tuberculosis.
# 80              Raktajroga                              Diseases of blood.
# 77             Pittajaroga                Diseases related to Pitta dosha.
# 66               Gandamala                                    Tonsillitis.
# 40             Vranashotha                             Swelling of wounds.
# 18              Urahkshata                                   Chest injury.
# 152             Karnasrava                                  Ear discharge.
#
#                                       English_Symptoms  common_words
# 37   fever, diarrhea, malnutrition, or respiratory ...             4
# 291  Fever,Loose Stools or Diarrhea,Abdominal Disco...             2
# 235  Swelling,Redness,Fever,Pus Discharge,Limited M...             1
# 198  Abdominal cramps, Pain, Bloating, Nausea, Vomi...             1
# 212  abdominal pain, bloating, diarrhea, nausea, we...             1
# 214  persistent elevated body temperature, fatigue,...             1
# 217  Fever, Cough, Fatigue, Headache, Joint pain, R...             1
# 224  Alterations in bowel habits,Abdominal pain,Blo...             1
# 234  Burning Sensation,Hyperacidity,Nausea,Vomiting...             1
# 252  Swelling, Fever, Lymphedema, Lymphadenitis, Sk...             1
# 176  Abdominal pain, Bloating, Gas, Diarrhea or con...             1
# 255  Bleeding from the Rectum,Abdominal Pain,Diarrh...             1
# 273  Bloody Stools,Diarrhea,Abdominal Pain,Anemia,D...             1
# 274  Abdominal Pain,Diarrhea,Constipation,Nausea an...             1
# 280  Watery Diarrhea,Vomiting,Dehydration,Rapid Hea...             1
# 287  Painful Urination,Foul-Smelling Urine,Frequent...             1
# 189  Erythema (redness), Swelling, Warmth, Pain, Fe...             1
# 3                   fever,bleding,infection,depression             1
# 15        chills, vomiting, diarrhea, and dehydration.             1
# 146  Excessive loss of Excretion Fasting Symptoms,O...             1
# 120  weakness ,shortness of breath, Kasa ,cough ,fe...             1
# 110  headache, fainting, giddiness, stiffness in ba...             1
# 96                   headache,fever,vomiting,dizziness             1
# 94    Burning pain, Difficult to engulfed the food,...             1
# 88   weakness , shortness of breath, cough ,fever ,...             1
# 86   Fever, Mouth ulcer, headache, burning sensatio...             1
# 85                headache,fever,cold,loss of appetite             1
# 80   hirst, fever, ulcers, burning sensation, chapp...             1
# 77   fever,vomiting,heatburn,irritability,inflammat...             1
# 66               pain, fever, or difficulty swallowing             1
# 40   Pain, redness, or heat in the affected area,Bl...             1
# 18   Chest pain, cough, or difficulty breathing,Hem...             1
# 152  Ear pain,itching,Ringing in the ear,Fever,Redn...             1
